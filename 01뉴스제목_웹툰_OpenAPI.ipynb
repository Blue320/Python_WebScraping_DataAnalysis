# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# reqeusts, bs4 import
import requests
import bs4

# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기

print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res.status_code, res.ok)

# 응답(response)이 OK 이면
if res.ok:
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, 'html.parser')

    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    print(len(soup.select("div.sa_text a[href*='mnews/article']")))
    a_tags = soup.select("div.sa_text a[href*='mnews/article']")
    print(type(a_tags))

    # <a> 태그 리스트 순회하기
    for a_tag in a_tags:
        title = a_tag.text.strip() #<a>제목<a>
        link = a_tag['href'] #<a href="link">title</a>
        print(title, link)
# 응답(response)이 Error 이면 status code 출력    
else:
    print(f'Error code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# 88
# <class 'bs4.element.ResultSet'>
# 국내 구글 이용자수, 네이버 첫 추월…챗GPT도 다음의 2.6배 https://n.news.naver.com/mnews/article/654/0000194662
#  https://n.news.naver.com/mnews/article/comment/654/0000194662
# 플리토, 2분기 흑자 전환…AI 통번역 솔루션 실적 견인 https://n.news.naver.com/mnews/article/243/0000101475
#  https://n.news.naver.com/mnews/article/comment/243/0000101475
# 웹툰 엔터, 2분기 매출 5천억원…전년 동기比 2.8% 감소 https://n.news.naver.com/mnews/article/001/0016243543
#  https://n.news.naver.com/mnews/article/comment/001/0016243543
# AI·로봇이 24시간 실험…과기정통부, 자율실험실 협의체 출범 https://n.news.naver.com/mnews/article/056/0012235277
#  https://n.news.naver.com/mnews/article/comment/056/0012235277
# 구글, 한국 앱 개발자 수수료 최저 10%로 낮춘다 https://n.news.naver.com/mnews/article/001/0016243989
#  https://n.news.naver.com/mnews/article/comment/001/0016243989
# 우체국 소포, 평소보다 늦게 옵니다…14·18일 배달원 휴식 https://n.news.naver.com/mnews/article/001/0016244101
#  https://n.news.naver.com/mnews/article/comment/001/0016244101
# 삼성SDS, 국가 AI 연구에 최신 GPU 자원 공급 https://n.news.naver.com/mnews/article/422/0000894450
#  https://n.news.naver.com/mnews/article/comment/422/0000894450
# 토종 플랫폼 ‘싸이월드’ 분쟁 격화… "양수도 무효" vs "합법적 절차" https://n.news.naver.com/mnews/article/029/0003041590
#  https://n.news.naver.com/mnews/article/comment/029/0003041590
# “AI 과학자들이 연구 결과 두고 서로 논쟁하는 시대 올 것” https://n.news.naver.com/mnews/article/366/0001185525
#  https://n.news.naver.com/mnews/article/comment/366/0001185525
# AI GPU 무대 해외로 넓히는 NHN클라우드, 전진기지는 '일본' https://n.news.naver.com/mnews/article/293/0000088887
#  https://n.news.naver.com/mnews/article/comment/293/0000088887
# 일본인들, 한국 중고시장까지 뒤진다…“없어서 못 판다”는 물건 정체가 https://n.news.naver.com/mnews/article/011/0004650572
#  https://n.news.naver.com/mnews/article/comment/011/0004650572
# 우주발사 매번 허가 안 받는다…반복 발사 시 '5년 일괄허가' https://n.news.naver.com/mnews/article/422/0000894542
#  https://n.news.naver.com/mnews/article/comment/422/0000894542
# SKT 부러운 네이버…"앤스로픽 주식 직접 못샀지만 VC펀드로 투자" https://n.news.naver.com/mnews/article/277/0005801551
#  https://n.news.naver.com/mnews/article/comment/277/0005801551
# 코어라인소프트, 美병원 판독실에 AI 심는다…북미 상용 워크플로우 확장 https://n.news.naver.com/mnews/article/018/0006349462
#  https://n.news.naver.com/mnews/article/comment/001/0016244268
# [챗ICT]또 부활한다는 싸이월드…석연찮은 '예토전생'이 남긴 것 https://n.news.naver.com/mnews/article/648/0000049707
#  https://n.news.naver.com/mnews/article/comment/648/0000049707
# 삼성SDS·엘리스그룹, 국가 AI 연구 인프라 책임진다…고성능 GPU 공급 https://n.news.naver.com/mnews/article/092/0002433608
#  https://n.news.naver.com/mnews/article/comment/092/0002433608
# 임무본부장 이어 차장도 떠났다…'수뇌부 공백' 맞은 우주청 https://n.news.naver.com/mnews/article/008/0005398291
#  https://n.news.naver.com/mnews/article/comment/008/0005398291
# [컨콜 종합] 정우진 NHN 대표 "성장 국면 출발점"…日 신작·양평 리전 키운다 https://n.news.naver.com/mnews/article/138/0002237366
#  https://n.news.naver.com/mnews/article/comment/138/0002237366
# 해외여행 데이터도 ‘이심’ 대세…통신사 로밍 첫 추월 https://n.news.naver.com/mnews/article/138/0002237365
#  https://n.news.naver.com/mnews/article/comment/138/0002237365
# 앱 수수료 개편 앞둔 구글…글로벌 부사장 "韓 개발자 성장 돕겠다" https://n.news.naver.com/mnews/article/003/0014119799
#  https://n.news.naver.com/mnews/article/comment/003/0014119799
# 음료 쏟자 청소봇 출동…엑스와이지가 구현한 지능형빌딩 [로봇onAI] https://n.news.naver.com/mnews/article/293/0000088881
#  https://n.news.naver.com/mnews/article/comment/293/0000088881
# 270억 털린 봉크…업비트·코인원 ‘상폐’, 빗썸은 거래 재개 https://n.news.naver.com/mnews/article/029/0003041749
#  https://n.news.naver.com/mnews/article/comment/029/0003041749
# [르포] 실외기 하나로 냉방·난방·온수까지… 제주 주택에 들어간 삼성전자 신기술 https://n.news.naver.com/mnews/article/366/0001185496
#  https://n.news.naver.com/mnews/article/comment/366/0001185496
# 삼성전자, '한국형 히트펌프'로 국내 시장 선도…“냉방·난방·온수 동시 제공” https://n.news.naver.com/mnews/article/030/0003456213
#  https://n.news.naver.com/mnews/article/comment/030/0003456213
# [르포] "LPG·기름보일러 가라"… 삼성전자가 제주서 찾은 'AI·친환경 히트펌프' 해법 https://n.news.naver.com/mnews/article/138/0002237362
#  https://n.news.naver.com/mnews/article/comment/138/0002237362
# 엔비디아 GPU 탑재 '날씨 AI팩토리' 개발…글로벌 예보 시장 공략 https://n.news.naver.com/mnews/article/052/0002391676
#  https://n.news.naver.com/mnews/article/comment/052/0002391676
# [AI는 지금] 中 AI 초저가 공세에 '균열'…딥시크, 가격 인상 압박받는 이유는 https://n.news.naver.com/mnews/article/092/0002433606
#  https://n.news.naver.com/mnews/article/comment/092/0002433606
# NHN, AI GPU 확장 본격화…30MW 증설·해외 계약 추진[컨콜] https://n.news.naver.com/mnews/article/018/0006349391
#  https://n.news.naver.com/mnews/article/comment/018/0006349391

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':'100','경제':'101','사회':'102','생활/문화':'103','세계':'104','IT/과학':'105' }

def print_news(section_name):  #print_new('생활/문화') 
    sid = section_dict.get(section_name, '102')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
    }

    # requests 의 get() 함수 호출하기 
    res = requests.get(url, headers=req_header)

    # 응답(response)이 OK 이면
    if res.ok:
        # 응답 (response)에서 text 추출
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, 'html.parser')

        # CSS 선택자
        # print(soup.select("div.sa_text a[href*='mnews/article']"))
        a_tags = soup.select("div.sa_text a[href*='mnews/article']")

        # <a> 태그 리스트 순회하기
        for a_tag in a_tags:
            title = a_tag.text.strip() #<a>제목<a>
            link = a_tag['href'] #<a href="link">title</a>
            print(title, link)
    # 응답(response)이 Error 이면 status code 출력    
    else:
        print(f'Error code = {res.status_code}')

# %%
print_news('정치')

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

# user-agent는 데이터 접근 시 인간처럼 보이게 하는 도구
req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)
        
    # binary 응답 데이터 가져오기
    img_data = res.content
    print(type(img_data))
    
    # url에서 파일명만 추출하기
    filename = os.path.basename(img_url)
    print(filename)
    
    # binday data를 file에 write하기
    with open(filename, 'wb') as f: # open 사용 시 img 파일 오픈 후 자동으로 닫아줌, wb : write binary
        print(f'writing to {filename}({len(img_data):,} bytes)')
        f.write(img_data)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=812354&no=208'

# user-agent는 데이터 접근 시 인간처럼 보이게 하는 도구
req_header = {
    'referer': webtoon_url,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

res = requests.get(webtoon_url, headers=req_header)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src$='.jpg']")))
    print(len(soup.select("img[src*='IMAG01_']")))
    #ResultSet 객체
    img_tags = soup.select("img[src*='IMAG01_']")
    #for img_tag in img_tags:
    #    #img_tag는 Tag 객체
    #    print(img_tag['src'])

    # 기존 방식
    img_url_list = []
    for img_tag in img_tags:
        img_url = img_tag['src']
        img_url_list.append(img_url)
    print(img_url_list)

    # list comprehension 방식
    img_url_list2 = [img_tag['src'] for img_tag in img_tags]
    print(img_url_list2)

    imgdir_name = 'img'
    
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for img_url in img_url_list2:
        # requests 의 get(url, headers) 함수 호출하기 
        res = requests.get(img_url, headers=req_header)
        # binary 응답 데이터 가져오기
        img_data = res.content    

        #img/xxxIMG01.jpg
        file_path = os.path.join(imgdir_name,os.path.basename(img_url))
        # binday data를 file에 write하기
        with open(file_path,'wb') as file:
            print(f'Writing to {file_path}({len(img_data):,} bytes)')
            file.write(img_data)

# %% [markdown]
# #### 리팩토링 코드
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
req_header = {
    'referer': url, 
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성 ( sub 디렉토리도 생성 )
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('img/f1.jpg','rb'),
    'img2': open('img/f2.jpg','rb'),
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url, files=upload_files)
print(res.status_code)
print(res.json()['files']['img1'])

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청
import os
import sys
import urllib.request

code = "0"
url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
key = "LATbkIeKn5PCugpM" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)

# %%
client_id = CLIENT_ID # 개발자센터에서 발급받은 Client ID 값
client_secret = CLIENT_SECRET # 개발자센터에서 발급받은 Client Secret 값
code = "1"
value = "7DS65" # captcha 이미지에 보이는 글자 입력

url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code + "&key=" + key + "&value=" + value
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import requests
from pprint import pprint
# pretty print, 모듈과 함수명이 같아 pprint.pprint()처럼 작성해야 되는 것을 방지하기 위해 import를 사용하지 않고 from import로 가져옴

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim' # 가장 유사도가 높은 순으로 정렬
}

url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

#items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)

# %%
import pandas as pd

print(pd.__version__)

blog_data = pd.read_json('data/blog.json')
print(blog_data.shape)

# %%
blog_data.head()

# %%
blog_data.columns

# %%
blog_data['bloggername'].unique()
